# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-aleislasb/blob/main/Semana%206_IBM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Module 3 - Exploratory Data Analysis

# %% [markdown]
# 3.1 Exploratory Data Analysis

# %%
#EDA means Exploratory Data Analysis, basically its function is to obtain main characters of data in order to have a better understanding of the main data and what is real

# %% [markdown]
# 3.2 Descriptive Statistics

# %%
#Helps to describe features of the data, and also describes an overall of what the complete data is. 
#One way to obtain a quick validation of statistical data of a dataframe is using describe(), gives a general distribution of the general dataframe. 
df.describe()

# %%
#Boxplots shows the complete distribution of different categories, showing it as a statistical object.
#Scatter plot shows the relationship between two variables, one can predict the other one, in order to obtain Y, tha scatter plot shows a complete graph based on points on which each point represent one given value.

# %% [markdown]
# 3.3 GroupBy in Python

# %%
#Used to make a union between categorical variables, and groups the data into subsets according to its different categories. this function can group by a single variable or multiple varibles.
df.Groupby()

# %%
#Pivot shows the values betweem columns and rows, it is easier to visualized grouped data.
df.pivot(index="drive-wheels", columns="body-style")

# %%
#A heatmap assigns a color intensity based on the value of the cell, this gives a clue of the general data.

# %% [markdown]
# 3.3 Analysis of Variance ANOVA

# %%
#ANOVA means Analysis of Variance, this shows the correlation of a categorical variable. 
#Shows two values, the f-value and the confidence values, complementing each other of it is representative for the complete data in general.

# %%
#In python we can perform an anova analysis, importing de Scipy package and using the function f_oneway.
#Here we need to extract the columns we need to compare and also group them

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)
